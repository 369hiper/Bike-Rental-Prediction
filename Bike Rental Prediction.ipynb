# %%
# Importing all the neccessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('F:/Downloads/day.csv')

# %%
df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %% [markdown]
#  ## Exploratory Data Analysis
#  Let's plot a heatmap with seaborn to see the correlation between the variables

# %%
top_corr_features
# Out:
# Index(['instant', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
## Correlation
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
top_corr_features
plt.figure(figsize=(30,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df1 = df

# Now we checking how our Data is Distributed, checking the normal distributions of the data
df1 = df.drop(['dteday'], axis = 1)
fig, axes = plt.subplots(nrows=4, ncols=4)

fig.set_size_inches(15, 12)
sns.distplot(df1['cnt'], ax=axes[0][0])
sns.distplot(df1['season'], ax=axes[0][1])
sns.distplot(df1['yr'], ax=axes[0][2])
sns.distplot(df1['mnth'], ax=axes[0][3])
sns.distplot(df1['holiday'], ax=axes[1][0])
sns.distplot(df1['weekday'], ax=axes[1][1])
sns.distplot(df1['workingday'], ax=axes[1][2])
sns.distplot(df1['weathersit'], ax=axes[1][3])
sns.distplot(df1['temp'], ax=axes[2][0])
sns.distplot(df1['atemp'], ax=axes[2][1])
sns.distplot(df1['hum'], ax=axes[2][2])
sns.distplot(df1['windspeed'], ax=axes[2][3])
sns.distplot(df1['casual'], ax=axes[3][0])
sns.distplot(df1['registered'], ax=axes[3][1])

# %% [markdown]
# # Outlier Analysis
# import numpy as np
# import pandas as pd
# outliers=[]
# def detect_outlier(data):
#
#     threshold=0.10
#     mean_1 = np.mean(data)
#     std_1 =np.std(data)
#
#
#     for y in data:
#         z_score= (y - mean_1)/std_1
#         if np.abs(z_score) > threshold:
#             outliers.append(y)
#     return outliers

# %%
# Here we are analyzing the data for detection of outliers                                        
fig, axes = plt.subplots(nrows=3, ncols=3)
fig.set_size_inches(12, 10)

sns.boxplot(df['temp'], ax= axes[0][1])
sns.boxplot(df['atemp'], ax= axes[0][0])
sns.boxplot(df['hum'], ax= axes[1][0])
sns.boxplot(df['windspeed'], ax= axes[1][1])
sns.boxplot(df['casual'], ax= axes[0][2])
sns.boxplot(df['registered'], ax = axes[2][0])
sns.boxplot(df['cnt'], ax= axes[2][1])
sns.boxplot(df['season'], ax= axes[2][2])
sns.boxplot(df['weekday'], ax= axes[1][2])

# %%
fig, axes = plt.subplots(nrows=3, ncols=4)
fig.set_size_inches(15, 10)
sns.boxplot(data=df, y="cnt", orient= "v", ax=axes[0][0])
sns.boxplot(data=df, y="cnt",x="season", orient= "v", ax=axes[0][1])
sns.boxplot(data=df, y="cnt",x="workingday", orient= "v", ax=axes[1][0])
sns.boxplot(data=df, y="cnt",x="weekday", orient= "v", ax=axes[2][0])
sns.boxplot(data=df, y="cnt",x="hum", orient= "v", ax=axes[1][1])
sns.boxplot(data=df, y="cnt",x="windspeed", orient= "v", ax=axes[1][2])
sns.boxplot(data=df, y="cnt",x="mnth", orient= "v", ax=axes[2][2])
sns.boxplot(data=df, y="temp",x="hum", orient= "v", ax=axes[1][2])
sns.boxplot(data=df, y="season",x="temp", orient= "v", ax=axes[1][2])
sns.boxplot(data=df, y="windspeed",x="cnt", orient= "v", ax=axes[2][1])
sns.boxplot(data=df, y="casual",x="cnt", orient= "v", ax=axes[0][2])
sns.boxplot(data=df, y="holiday",x="cnt", orient= "v", ax=axes[1][3])

# %% [markdown]
# # Removing the Outliers!

# %%
dailyDataWithoutOutliers = df[np.abs(df["cnt"]-df["cnt"].mean())<=(3*df["cnt"].std())]

# %%
dailyDataWithoutOutliers
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...

# %%
# Let's See how many outliers there were
print("Data with Outliers",df.shape)
print("Data without Outliers",dailyDataWithoutOutliers.shape)
# Out:
# Data with Outliers (731, 16)
# Data without Outliers (731, 16)

# %%
# Creating a Correlation Matrix

corrMatt = df[["holiday", "weekday", "workingday","temp","atemp","casual","registered","hum","windspeed","cnt"]].corr()
#Converting this to an array
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)] = False
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.heatmap(corrMatt, mask=mask, vmax=.8, square=True, annot=True)

# %% [markdown]
# INFERENCES FROM THE ABOVE HEATMAP--
# self realtion i.e. of a feature to itself is equal to 1 as expected.
#
# temp and atemp are highly related as expected.
#
# humidity is almost positvely related to count as expected as the weather is humid people will like to travel on a bike.
#
# also note that casual and working day are highly inversely related as you would expect.
#
# Also note that count and holiday are highly inversely related as you would expect.
#
# Also note that temp(or atemp) highly effects the count.
#
# Also note that weather and count are highly inversely related. This is bcoz for uour data as weather increases from (1 to 4) implies that weather is getting more worse and so lesser people will rent bikes.
#
# registered/casual and count are highly related which indicates that most of the bikes that are rented are registered.
#
# similarly we can draw some more inferences like weather and humidity and so on... .

# %%
fig,(ax1, ax2, ax3) = plt.subplots(ncols=3)
fig.set_size_inches(12, 5)
sns.regplot(x='temp', y='cnt', data=df, ax=ax1)
sns.regplot(x='windspeed', y='cnt', data= df, ax=ax3)
sns.regplot(x='hum', y='cnt', data= df, ax=ax2)

# %%
from scipy import stats
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(12, 10)
sns.distplot(df['cnt'], ax=axes[0][0])
stats.probplot(df['cnt'], dist='norm', fit=True, plot=axes[0][1])
sns.distplot(np.log(dailyDataWithoutOutliers["cnt"]),ax=axes[1][0])
stats.probplot(np.log1p(dailyDataWithoutOutliers["cnt"]), dist='norm', fit=True, plot=axes[1][1])
# Out:
# ((array([-3.10612952, -2.83371839, -2.68121219, -2.57340905, -2.48915191,
#          -2.41955673, -2.36001798, -2.30782877, -2.26125818, -2.21912992,
#          -2.18060696, -2.14507173, -2.11205508, -2.08119197, -2.05219258,
#          -2.0248228 , -1.99889075, -1.97423711, -1.95072808, -1.92825019,
#          -1.90670633, -1.88601273, -1.8660966 , -1.84689427, -1.82834975,
#          -1.81041348, -1.79304141, -1.77619419, -1.75983653, -1.74393663,
#          -1.72846577, -1.71339788, -1.69870925, -1.68437825, -1.67038506,
#          -1.6567115 , -1.64334086, -1.63025771, -1.6174478 , -1.60489794,
#          -1.59259587, -1.58053022, -1.56869036, -1.55706641, -1.54564912,
#          -1.53442983, -1.52340042, -1.51255328, -1.50188124, -1.49137757,
#          -1.4810359 , -1.47085025, -1.46081495, -1.45092464, -1.44117426,
#          -1.431559  , -1.4220743 , -1.41271583, -1.40347947, -1.39436132,
#          -1.38535765, -1.3764649 , -1.36767969, -1.35899879, -1.35041911,
# ...

# %%
# Splitting the dependent and independent variables

X = df.iloc[:, :-1]
y = df.iloc[:, 15]
X = df.drop("dteday", axis=1)

# %%
# Splitting the Dataset into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=1)

# %%
# Fitting the Multiple Linear Regression Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Predicting the Test Set results
y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 1.0

# %% [markdown]
# # Support Vector Regression

# %%
from sklearn.svm import SVR
clf = SVR(gamma='scale', C=1.0, epsilon=0.2)
clf.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='scale',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred1 = clf.predict(X_test)

# %%
score = r2_score(y_test, y_pred1)

# %%
score
# Out:
# 0.03546093281671636

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
# from sklearn.datasets import make_regression
regr = RandomForestRegressor(max_depth=2, random_state=0,
                     n_estimators=100)

# %%
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_predict = regr.predict(X_test)
score = r2_score(y_test, y_predict)

# %%
score
# Out:
# 0.9517200883475954
